# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data/fifa19data.csv',index_col=0)

# %%
df.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
#
#   Composure Marking  StandingTackle SlidingTackle  GKDiving  GKHandling  \
# 0      96.0    33.0            28.0          26.0       6.0        11.0
# 1      95.0    28.0            31.0          23.0       7.0        11.0
# 2      94.0    27.0            24.0          33.0       9.0         9.0
# 3      68.0    15.0            21.0          13.0      90.0        85.0
# 4      88.0    68.0            58.0          51.0      15.0        13.0
#
#    GKKicking GKPositioning GKReflexes Release Clause
# 0       15.0          14.0        8.0        €226.5M
# 1       15.0          14.0       11.0        €127.1M
# 2       15.0          15.0       11.0        €228.1M
# 3       87.0          88.0       94.0        €138.6M
# 4        5.0          10.0       13.0        €196.4M
#
# [5 rows x 88 columns]

# %%
df.columns # some of these are unnecessary, and we'll get rid of them
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
df.drop(columns=['ID','Photo','Flag','Club Logo','Work Rate','Weak Foot','Preferred Foot','Body Type','Real Face',
                 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
                 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
       'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
       'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB'], inplace=True)

# %%
df.dropna(subset=['Height','Weight'], inplace=True) # drop all rows where either of height or weight is missing

# %% [markdown]
# **In the following few lines, we'll be converting the current string representations of heights, weights, values, wages and release clauses to their respective default formats, i.e. heights to inches, weights to  lbs, values, wages and release clauses to 'thousands of euros'**

# %%
def to_inches(row):
    lst = row.split("'")
    lst = pd.to_numeric(lst)
    new_height = (lst[0] * 12) + lst[1]
    return new_height

# %%
df['Height'] = df['Height'].apply(to_inches)

# %%
def weight_in_num(row):
    lst = row.split('lbs')
    lst = pd.to_numeric(lst)
    new_weight = lst[0]
    return new_weight

# %%
df['Weight'] = df['Weight'].apply(weight_in_num)

# %%
def value_change(row): #converting everything in terms of 'thousands of euros'
    if row[-1] == 'M':
        row = row[1:-1] # getting rid of euro and million sign
        num = pd.to_numeric(row)
        num = num * 1000
        return num
    else:
        return pd.to_numeric(row[1:-1])

# %%
df['Value'] = df['Value'].apply(value_change)

# %%
def release_clause_change(row):
    if row[-1] == 'M':
        row = row[1:-1]
        num = pd.to_numeric(row)
        num = num * 1000
        return num
    else:
        return pd.to_numeric(row[1:-1])

# %%
df['Release Clause'] = df[df['Release Clause'].notnull()]['Release Clause'].apply(release_clause_change)

# %%
def wage_change(row): # make wages in thousands of euros
    return pd.to_numeric(row[1:-1])

# %%
df['Wage'] = df['Wage'].apply(wage_change)

# %%
df.head(2)
# Out:
#                 Name  Age Nationality  Overall  Potential          Club  \
# 0           L. Messi   31   Argentina       94         94  FC Barcelona
# 1  Cristiano Ronaldo   33    Portugal       94         94      Juventus
#
#       Value   Wage  Special  International Reputation  ...  Composure Marking  \
# 0  110500.0  565.0     2202                       5.0  ...       96.0    33.0
# 1   77000.0  405.0     2228                       5.0  ...       95.0    28.0
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0            28.0           26.0       6.0        11.0       15.0
# 1            31.0           23.0       7.0        11.0       15.0
#
#    GKPositioning  GKReflexes  Release Clause
# 0           14.0         8.0        226500.0
# 1           14.0        11.0        127100.0
#
# [2 rows x 49 columns]

# %%
sns.scatterplot(y='Special',x='SprintSpeed',data=df)
# players with more 'special' rating tend to be 'speedier'

# %%
sns.distplot(df.Age)
# almost represents a normal distribution, (except for a few very old guys, which is good to see.
# Mr. Gauss would be a happy man.

# %% [markdown]
# **Just in case you wanted to know the top players right now**

# %%
top_class_players = df[df['Value'] > 40000]
top_class_players.head(10)

# players with a market value of more than 40 million euros
# NOTE: ('40000' in the filter is actually in terms of thousands of euros, as explained earlier)
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0           L. Messi   31   Argentina       94         94
# 1  Cristiano Ronaldo   33    Portugal       94         94
# 2          Neymar Jr   26      Brazil       92         93
# 3             De Gea   27       Spain       91         93
# 4       K. De Bruyne   27     Belgium       91         92
# 5          E. Hazard   27     Belgium       91         91
# 6          L. Modrić   32     Croatia       91         91
# 7          L. Suárez   31     Uruguay       91         91
# 8       Sergio Ramos   32       Spain       91         91
# 9           J. Oblak   25    Slovenia       90         93
#
#                   Club     Value   Wage  Special  International Reputation  \
# 0         FC Barcelona  110500.0  565.0     2202                       5.0
# 1             Juventus   77000.0  405.0     2228                       5.0
# 2  Paris Saint-Germain  118500.0  290.0     2143                       5.0
# 3    Manchester United   72000.0  260.0     1471                       4.0
# 4      Manchester City  102000.0  355.0     2281                       4.0
# 5              Chelsea   93000.0  340.0     2142                       4.0
# 6          Real Madrid   67000.0  420.0     2280                       4.0
# 7         FC Barcelona   80000.0  455.0     2346                       5.0
# 8          Real Madrid   51000.0  380.0     2201                       4.0
# 9      Atlético Madrid   68000.0   94.0     1331                       3.0
#
#    ...  Composure Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0  ...       96.0    33.0            28.0           26.0       6.0
# 1  ...       95.0    28.0            31.0           23.0       7.0
# 2  ...       94.0    27.0            24.0           33.0       9.0
# 3  ...       68.0    15.0            21.0           13.0      90.0
# 4  ...       88.0    68.0            58.0           51.0      15.0
# 5  ...       91.0    34.0            27.0           22.0      11.0
# 6  ...       84.0    60.0            76.0           73.0      13.0
# 7  ...       85.0    62.0            45.0           38.0      27.0
# 8  ...       82.0    87.0            92.0           91.0      11.0
# 9  ...       70.0    27.0            12.0           18.0      86.0
#
#    GKHandling  GKKicking  GKPositioning  GKReflexes  Release Clause
# 0        11.0       15.0           14.0         8.0        226500.0
# 1        11.0       15.0           14.0        11.0        127100.0
# 2         9.0       15.0           15.0        11.0        228100.0
# 3        85.0       87.0           88.0        94.0        138600.0
# 4        13.0        5.0           10.0        13.0        196400.0
# 5        12.0        6.0            8.0         8.0        172100.0
# 6         9.0        7.0           14.0         9.0        137400.0
# 7        25.0       31.0           33.0        37.0        164000.0
# 8         8.0        9.0            7.0        11.0        104600.0
# 9        92.0       78.0           88.0        89.0        144500.0
#
# [10 rows x 49 columns]

# %% [markdown]
# And these are the teams for whom these players play... (Do you see your team here?!)

# %%
top_class_players.groupby('Club')['Name'].count().sort_values(ascending=False) # No wonder Madrid won 4 out of the last 6 Champions Leagues!
# Out:
# Club
# Real Madrid            10
# Manchester City         9
# FC Barcelona            7
# FC Bayern München       6
# Atlético Madrid         5
# Liverpool               4
# Juventus                4
# Paris Saint-Germain     4
# Napoli                  4
# Manchester United       4
# Tottenham Hotspur       3
# Arsenal                 3
# Lazio                   2
# Inter                   2
# Chelsea                 2
# Olympique Lyonnais      2
# Sporting CP             1
# Milan                   1
# Borussia Dortmund       1
# Name: Name, dtype: int64

# %%
sns.boxplot(y='Vision',x='Height',data=df) # reaffirms the notion that shorter players are more creative, for eg. Cazorla, Messi, Mata, Silva etc.

# %%
sns.boxplot(y='Balance',x='Height',data=df) # and this is why shorter players are quicker, they can balance themseles better!

# %%
sns.boxplot(y='Strength',x='Height',data=df) # reaffirms the notion that shorter players are kinda weaker in duels

# %% [markdown]
# **Now a bombshell is about to be dropeed!**

# %%
df.corr()['Age'] # no visible correlation anywhere! reaffirms the notion that age is just a number!
# Out:
# Age                         1.000000
# Overall                     0.453069
# Potential                  -0.252281
# Value                       0.078452
# Wage                        0.143944
# Special                     0.236875
# International Reputation    0.253765
# Skill Moves                 0.027649
# Height                      0.082604
# Weight                      0.230213
# Crossing                    0.130545
# Finishing                   0.068660
# HeadingAccuracy             0.147183
# ShortPassing                0.132894
# Volleys                     0.142472
# Dribbling                   0.010166
# Curve                       0.143276
# FKAccuracy                  0.193467
# LongPassing                 0.181310
# BallControl                 0.084969
# Acceleration               -0.158667
# SprintSpeed                -0.151682
# Agility                    -0.019395
# Reactions                   0.453124
# Balance                    -0.089877
# ShotPower                   0.156947
# Jumping                     0.177167
# Stamina                     0.097793
# Strength                    0.332798
# LongShots                   0.155096
# Aggression                  0.265190
# Interceptions               0.197845
# Positioning                 0.082443
# Vision                      0.187422
# Penalties                   0.139535
# Composure                   0.391023
# Marking                     0.142817
# StandingTackle              0.119745
# SlidingTackle               0.103089
# GKDiving                    0.101277
# GKHandling                  0.106419
# GKKicking                   0.104964
# GKPositioning               0.116402
# GKReflexes                  0.103313
# Release Clause              0.060760
# Name: Age, dtype: float64

# %% [markdown]
# **Now comes the main analysis, predicting the World Cup 2022 contenders!**

# %% [markdown]
# We need a list of people who are raw today, but hold potential to be bright in the future... at least in the eyes of guys at FIFA!

# %%
df_raw_players_with_potential = df[(df['Overall'] <= 70) & (df['Potential'] > 80)]

# %% [markdown]
# This will come in handy if you wanna get a feel of someone like Arsene Wenger or Guardiola or Klopp and develop raw players into superstars!

# %%
df_raw_players_with_potential.sort_values(by='Potential',ascending=False)  # watch out for these players!
# Out:
#                    Name  Age     Nationality  Overall  Potential  \
# 7414          S. Tonali   18           Italy       68         89
# 6102         Riqui Puig   18           Spain       69         89
# 7758        P. Pellegri   17           Italy       67         88
# 6032             J. Arp   18         Germany       69         88
# 5007         Kangin Lee   17  Korea Republic       70         88
# 9485            S. Diop   18          France       66         87
# 5121     C. Hudson-Odoi   17         England       70         87
# 7217       Sergio Gómez   17           Spain       68         87
# 8191           A. Gomes   17         England       67         87
# 7952         A. Bastoni   19           Italy       67         87
# 11457       W. Geubbels   16          France       64         86
# 13927           A. Dabo   17          France       62         86
# 5383        J. Dilrosun   20     Netherlands       70         86
# 10801         E. Ampadu   17           Wales       65         86
# 8145          A. Gouiri   18          France       67         86
# 9935         C. Früchtl   18         Germany       65         86
# 8700     M. Gibbs-White   18         England       67         86
# 6559        Brahim Díaz   18           Spain       69         86
# 5259           S. Özcan   20         Germany       70         85
# 11451           T. Kubo   17           Japan       64         85
# 5407           M. Diaby   18          France       70         85
# 5528            Rogério   20          Brazil       70         85
# 10087          T. Chong   18     Netherlands       65         85
# 7322           J. David   18          Canada       68         85
# 5754           N. Cozza   19          France       69         85
# 12166       E. Loiodice   17          France       63         85
# 7405          M. Barrow   19          Gambia       68         85
# 11579     E. Smith Rowe   17         England       64         85
# 5953            T. Weah   18   United States       69         85
# 10361                 Aberdeen  1100.0   1.0     1763
# 10432           Club Brugge KV  1100.0   3.0     1508
# 6547              Norwich City  1600.0  13.0     1936
# 6090    Club Atlético Talleres  1800.0   5.0     1712
# 11776                   Ascoli   925.0   5.0     1673
# 6144           FC Nordsjælland  1600.0   3.0     1667
# 6250                     Genoa  1900.0  30.0     1508
# 8424                   FC Metz  1600.0   2.0     1540
# 6268                     Genoa  1600.0   4.0     1710
# 6287             FC Basel 1893  1900.0  10.0     1784
# 6289      RC Strasbourg Alsace  1700.0   6.0     1597
# 11573                     Roma   850.0   4.0     1419
# 6306                AZ Alkmaar  1900.0   6.0     1715
# 11468          PFC CSKA Moscow   975.0   1.0     1649
# 6316           Manchester City  1700.0  28.0     1745
# 11352       Fortuna Düsseldorf   975.0   3.0     1496
# 11347        Tottenham Hotspur   925.0   7.0     1615
# 6437               CD Nacional  1900.0   5.0     1685
# 11153      CF Rayo Majadahonda   975.0   5.0     1542
# 11002                Girona FC  1000.0   4.0     1632
# 6479                   Odds BK  1500.0   2.0     1169
# 6491                  SC Braga  1900.0   6.0     1702
# 10837                  Pescara  1200.0   7.0     1541
# 6496            Wigan Athletic  1600.0  23.0     1655
# 6514            RSC Anderlecht  1600.0   4.0     1653
# 10567            Villarreal CF  1200.0   4.0     1553
# 6517            1. FC Nürnberg  1700.0   7.0     1633
# 6544                 Feyenoord  1800.0   4.0     1626
# 8196     San Martin de Tucumán  1500.0   5.0     1762
#
#        International Reputation  ...  Composure Marking  StandingTackle  \
# 7414                        1.0  ...       69.0    62.0            64.0
# 6102                        1.0  ...       70.0    53.0            57.0
# 7758                        1.0  ...       50.0    19.0            12.0
# 6032                        1.0  ...       58.0    18.0            17.0
# 5007                        1.0  ...       68.0    26.0            23.0
# 9485                        1.0  ...       64.0    30.0            31.0
# 5121                        1.0  ...       64.0    22.0            33.0
# 7217                        1.0  ...       58.0    58.0            37.0
# 8191                        1.0  ...       69.0    36.0            38.0
# 7952                        1.0  ...       52.0    73.0            74.0
# 11457                       1.0  ...       63.0    27.0            21.0
# 13927                       1.0  ...       40.0    62.0            65.0
# 5383                        1.0  ...       49.0    50.0            48.0
# 10801                       1.0  ...       64.0    66.0            67.0
# 8145                        1.0  ...       69.0    22.0            13.0
# 9935                        1.0  ...       22.0    16.0            10.0
# 8700                        1.0  ...       70.0    52.0            49.0
# 6559                        1.0  ...       62.0    43.0            23.0
# 5259                        1.0  ...       69.0    65.0            76.0
# 11451                       1.0  ...       60.0    40.0            43.0
# 5407                        1.0  ...       60.0    39.0            39.0
# 5528                        1.0  ...       68.0    69.0            68.0
# 10087                       1.0  ...       60.0    43.0            46.0
# 7322                        1.0  ...       63.0    21.0            21.0
# 5754                        1.0  ...       60.0    70.0            70.0
# 12166                       1.0  ...       63.0    52.0            56.0
# 7405                        1.0  ...       60.0    45.0            20.0
# 11579                       1.0  ...       60.0    37.0            30.0
# 5953                        1.0  ...       66.0    30.0            26.0
# 5057                        1.0  ...       72.0    32.0            30.0
# ...                         ...  ...        ...     ...             ...
# 6599                        1.0  ...       60.0    67.0            73.0
# 8196         15.0             NaN
#
# [286 rows x 49 columns]

# %% [markdown]
# Wouldn't surprise me to find scouts of the giant clubs sitting in the stands of these teams' games: of AS Monaco, Hertha Berlin, Anderlecht, etc

# %%
df_raw_players_with_potential.groupby('Club')['Club'].count().sort_values(ascending=False)
# Out:
# Club
# FC Barcelona               6
# AS Monaco                  5
# Chelsea                    4
# Hertha BSC                 4
# RSC Anderlecht             4
# Paris Saint-Germain        4
# Olympique Lyonnais         4
# Manchester City            4
# Liverpool                  4
# Heart of Midlothian        4
# FC Red Bull Salzburg       4
# FC Basel 1893              4
# FC Bayern München          4
# Girona FC                  3
# Hamburger SV               3
# Atalanta                   3
# Genoa                      3
# Everton                    3
# FC Schalke 04              3
# Club Brugge KV             3
# Norwich City               3
# Pescara                    3
# Rangers FC                 3
# SV Werder Bremen           3
# Shakhtar Donetsk           3
# 1. FC Köln                 3
# Wigan Athletic             3
# Swansea City               3
# TSG 1899 Hoffenheim        3
# Arsenal                    3
#                           ..
# RC Strasbourg Alsace       1
# RB Leipzig                 1
# FC Nantes                  1
# FC Nordsjælland            1
# FC Porto                   1
# FC Zürich                  1
# Feyenoord                  1
# Frosinone                  1
# Grasshopper Club Zürich    1
# Hannover 96                1
# Ipswich Town               1
# KAS Eupen                  1
# KRC Genk                   1
# Kilmarnock                 1
# LOSC Lille                 1
# Le Havre AC                1
# Legia Warszawa             1
# Los Angeles FC             1
# MSV Duisburg               1
# Milan                      1
# Molde FK                   1
# Montpellier HSC            1
# Nîmes Olympique            1
# Odds BK                    1
# Once Caldas                1
# Palermo                    1
# Parma                      1
# Preston North End          1
# Queens Park Rangers        1
# KAA Gent                   1
# Name: Club, Length: 168, dtype: int64

# %% [markdown]
# Now, for the World Cup probables, we'll set the benchmark at the age of the player being no more than 33 in 2022, i.e. 30 today, and a 'Potential' of no less than 75, if he is to be in contention for a place in the World Cup 2022 squad... pretty reasonable I guess

# %%
df_worldcup2022_probables = df[(df.Age<=30) & (df.Potential>75)]

# %%
df_worldcup2022_probables.sample()
# Out:
#            Name  Age Nationality  Overall  Potential             Club   Value  \
# 4024  F. Chalov   20      Russia       71         83  PFC CSKA Moscow  4300.0
#
#       Wage  Special  International Reputation  ...  Composure Marking  \
# 4024   1.0     1653                       1.0  ...       72.0    23.0
#
#       StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 4024            26.0           23.0       7.0         6.0       11.0
#
#       GKPositioning  GKReflexes  Release Clause
# 4024            6.0        11.0         10300.0
#
# [1 rows x 49 columns]

# %% [markdown]
# But this list also contains players from teams who have less than 20 players listed. And a world-cup preliminary squad is more than that, hence we'll happily drop those rows - anyway those teams wouldn't be fancied to win, if they don't have enough good players listed on FIFA.

# %%
df_worldcup2022_probables.groupby('Nationality')['Potential'].count()
# Out:
# Nationality
# Albania                   5
# Algeria                  20
# Angola                    3
# Antigua & Barbuda         1
# Argentina               257
# Armenia                   1
# Australia                13
# Austria                  47
# Belgium                  94
# Benin                     1
# Bolivia                   1
# Bosnia Herzegovina       15
# Brazil                  220
# Bulgaria                  2
# Burkina Faso              6
# Burundi                   1
# Cameroon                 26
# Canada                    7
# Cape Verde                7
# Central African Rep.      1
# Chad                      2
# Chile                    66
# China PR                  4
# Colombia                124
# Congo                     4
# Costa Rica                5
# Croatia                  47
# Cuba                      1
# Curacao                   1
# Cyprus                    1
#                        ...
# Paraguay                 22
# Peru                      9
# Poland                   36
# Portugal                131
# Republic of Ireland      21
# Romania                  19
# Russia                   35
# Saudi Arabia              6
# Scotland                 49
# Senegal                  34
# Serbia                   46
# Slovakia                 15
# Slovenia                 14
# South Africa             13
# Spain                   389
# Sweden                   41
# Switzerland              68
# Syria                     2
# Tanzania                  1
# Togo                      3
# Tunisia                   7
# Turkey                   63
# Ukraine                  32
# United Arab Emirates      1
# United States            70
# Uruguay                  41
# Venezuela                24
# Wales                    22
# Zambia                    2
# Zimbabwe                  1
# Name: Potential, Length: 111, dtype: int64

# %%
df_worldcup2022_probables.groupby('Nationality').filter(lambda x: len(x) > 20)['Nationality'].value_counts()
# Out:
# Spain                  389
# England                316
# France                 295
# Germany                279
# Argentina              257
# Brazil                 220
# Italy                  177
# Portugal               131
# Colombia               124
# Netherlands            123
# Belgium                 94
# Mexico                  73
# United States           70
# Switzerland             68
# Chile                   66
# Turkey                  63
# Denmark                 59
# Scotland                49
# Nigeria                 48
# Austria                 47
# Croatia                 47
# Serbia                  46
# Norway                  42
# Uruguay                 41
# Sweden                  41
# Ivory Coast             39
# Poland                  36
# Greece                  36
# Russia                  35
# Ghana                   35
# Senegal                 34
# Ukraine                 32
# Japan                   27
# Czech Republic          26
# Morocco                 26
# Cameroon                26
# Venezuela               24
# Paraguay                22
# Wales                   22
# Republic of Ireland     21
# Name: Nationality, dtype: int64

# %%
df_worldcup2022_probables = df_worldcup2022_probables[df_worldcup2022_probables.groupby('Nationality')['Nationality'].transform('size') > 20]

# %% [markdown]
# ***NOW COMES THE MAIN PREDICTIONS!***

# %%
df_worldcup2022_probables.groupby('Nationality')['Potential'].mean().sort_values(ascending=False)
# Out:
# Nationality
# Croatia                80.914894
# France                 80.708475
# Portugal               80.511450
# Uruguay                80.365854
# Brazil                 80.327273
# Italy                  80.288136
# Belgium                80.287234
# Senegal                80.235294
# Spain                  80.079692
# Poland                 80.027778
# Serbia                 80.000000
# Wales                  79.954545
# Ukraine                79.875000
# Netherlands            79.796748
# Paraguay               79.727273
# Ivory Coast            79.717949
# Germany                79.616487
# England                79.607595
# Russia                 79.514286
# Morocco                79.461538
# Argentina              79.459144
# Nigeria                79.458333
# Japan                  79.333333
# Switzerland            79.235294
# Denmark                79.220339
# Czech Republic         79.192308
# Greece                 79.055556
# Cameroon               79.038462
# Scotland               78.918367
# Colombia               78.887097
# Venezuela              78.875000
# Austria                78.808511
# Ghana                  78.600000
# Turkey                 78.571429
# United States          78.457143
# Republic of Ireland    78.380952
# Sweden                 78.341463
# Norway                 78.333333
# Mexico                 78.328767
# Chile                  77.863636
# Name: Potential, dtype: float64

# %% [markdown]
# **No wonder Croatia and France feature at the top - both these teams had youthful squads in last year's World Cup, and reached the final, which means both of 'em will have more experienced squads in three years' time, and happier prospects for them both!**
